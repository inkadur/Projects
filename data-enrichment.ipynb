# %% [markdown]
# ## Data Enrichment with AI

# %% [markdown]
# ### Setup

# %% [markdown]
# ##### Create a dataset for storing the AI tables and another for storing the AI models

# %%
# %%bigquery
# CREATE SCHEMA `shidcs329e`.magazine_recipes_stg_ai
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# CREATE SCHEMA `shidcs329e`.remote_models
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ##### Before running this cell, create the remote connection and assign the IAM role `Vertex AI User` to the service account associated with the connection.

# %%
# %%bigquery
# create or replace model remote_models.gemini_pro
#   remote with connection `projects/shidcs329e/locations/us/connections/vertexconnection`
#   options (endpoint = 'gemini-pro');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Change 1: Detect Recipe 'TYPE' within Recipes table

# %%
# %%bigquery
# select *
# from magazine_recipes_stg.Recipes
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    recipe_id title subtitle  servings yield_unit  prep_min  cook_min  \
# 0       1471  None     None      <NA>       None      <NA>      <NA>
# 1       1559  None     None      <NA>       None      <NA>      <NA>
# 2       1509  None     None      <NA>       None      <NA>      <NA>
# 3       1458  None     None      <NA>       None      <NA>      <NA>
# 4       1567  None     None      <NA>       None      <NA>      <NA>
#
#    stnd_min source intro  ... rating  ease_of_prep  note  type  page  \
# 0      <NA>   None  None  ...   <NA>          None  None  None  <NA>
# 1      <NA>   None  None  ...   <NA>          None  None  None  <NA>
# 2      <NA>   None  None  ...   <NA>          None  None  None  <NA>
# 3      <NA>   None  None  ...   <NA>          None  None  None  <NA>
# 4      <NA>   None  None  ...   <NA>          None  None  None  <NA>
#
#    slowcooker  link last_made data_source                        load_time
# 0        None  None       NaT        bird 2024-01-30 01:08:47.612652+00:00
# 1        None  None       NaT        bird 2024-01-30 01:08:47.612652+00:00
# 2        None  None       NaT        bird 2024-01-30 01:08:47.612652+00:00
# 3        None  None       NaT        bird 2024-01-30 01:08:47.612652+00:00
# 4        None  None       NaT        bird 2024-01-30 01:08:47.612652+00:00
#
# [5 rows x 21 columns]

# %%
# there appear to be many null records, the LLM will not be able to predict if there is not data
# %%bigquery
select count(recipe_id)
from magazine_recipes_stg.Recipes
where title is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0  153

# %%
# %%bigquery
# select count(quantity_id) from magazine_recipes_stg.Quantity
# where recipe_id in (select recipe_id from magazine_recipes_stg.Recipes where title is null)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0    0

# %%
# the null records are not in the junction table so there will not be orphan records if we delete them
# %%bigquery
create or replace table magazine_recipes_stg.Recipes as
select * from magazine_recipes_stg.Recipes
where title is not null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from magazine_recipes_stg.Recipes
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    recipe_id                             title subtitle  servings yield_unit  \
# 0        143  Prosciutto apple flatbread pizza     None      <NA>       None
# 1        141                Soy Mustard Salmon     None      <NA>       None
# 2        139                 Tomato Basil Soup     None      <NA>       None
# 3        142              Dill Cucumber Salmon     None      <NA>       None
# 4        145                            Scones     None      <NA>       None
#
#    prep_min  cook_min  stnd_min                   source intro  ... rating  \
# 0        45      <NA>      <NA>        Sheet Pan Suppers  None  ...      3
# 1        20      <NA>      <NA>        Sheet Pan Recipes  None  ...      4
# 2        45      <NA>      <NA>        Good Housekeeping  None  ...      4
# 3        30      <NA>      <NA>        Sheet Pan Suppers  None  ...      4
# 4        45      <NA>      <NA>  Pinterest,Taste of Home  None  ...      5
#
#    ease_of_prep                     note           type  page  slowcooker  \
# 0   Fairly Easy                     None      Main Dish  <NA>        None
# 1   Fairly Easy                     None      Main Dish    84        None
# 2       Average                     None      Main Dish    60        None
# 3       Average                     None      Main Dish  <NA>        None
# 4  Super Simple  Make dough night before  Baking Basics  <NA>        None
#
#    link   last_made data_source                        load_time
# 0  None  2018-09-23    airtable 2024-02-02 21:09:57.475069+00:00
# 1  None  2018-06-16    airtable 2024-02-02 21:09:57.475069+00:00
# 2  None  2019-01-12    airtable 2024-02-02 21:09:57.475069+00:00
# 3  None  2018-11-02    airtable 2024-02-02 21:09:57.475069+00:00
# 4  None  2017-05-13    airtable 2024-02-02 21:09:57.475069+00:00
#
# [5 rows x 21 columns]

# %%
# %%bigquery
# SELECT column_name, COUNT(1) AS nulls_count
# FROM magazine_recipes_stg.Recipes,
# UNNEST(REGEXP_EXTRACT_ALL(TO_JSON_STRING('magazine_recipes_stg.Recipes'), r'"(\w+)":null')) column_name
# GROUP BY column_name
# ORDER BY nulls_count DESC
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [column_name, nulls_count]
# Index: []

# %%
# Some Recipes already have a Type, other recipes do not!
# %%bigquery
select distinct(type) from magazine_recipes_stg.Recipes
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             type
# 0      Main Dish
# 1  Baking Basics
# 2      Side Dish
# 3           None
# 4          Drink
# 5        Dessert
# 6          Salad
# 7      Breakfast

# %%
# We don't really like the type 'Baking Basics'
# %%bigquery
select title from magazine_recipes_stg.Recipes
where type = 'Baking Basics'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                              title
# 0                           Scones
# 1          Brioche Chocolate Rolls
# 2  Chocolate Chip Irish Soda Bread
# 3                 Dutch Oven Bread
# 4                             Naan
# 5           Baking Powder Biscuits
# 6          Lemon Poppy Seed Scones
# 7                 Malteese Gilatti
# 8                   Pretzel Sticks
# 9                    Sugar Cookies

# %%
# Baking Basics is not that descriptive of a cateogry
#  most could just be recategorized as desserts or side dishes, so we will set the category to null for these records and let the LLM recategorize them
# %%bigquery
update magazine_recipes_stg.Recipes
set type = null
where type = 'Baking Basics'
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select distinct(type), count(*) from magazine_recipes_stg.Recipes
# group by type
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         type  f0_
# 0       None  892
# 1  Main Dish  102
# 2  Side Dish    9
# 3    Dessert   10
# 4      Drink    2
# 5      Salad    3
# 6  Breakfast    5

# %%
# category that would be useful but are not present: soup, appetizer

# %%
# %%bigquery
# declare prompt_query STRING default "Classify each recipe into one of these 8 categories (Main Dish, Side Dish, Dessert, Drink, Salad, Breakfast, Soup, Appetizer) with similar recipes in each category if the record does not already have a type. Assign each recipe to only one category. Return the output as json, include the recipe_id, title, and cateogry in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
#     from magazine_recipes_stg.Recipes
#     order by recipe_id
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"recipe_id":1,"title":"Chive Butter Radishes"...
# 1  ```json\n[\n  {\n    "recipe_id": 1,\n    "tit...
# 2  ```json\n[\n  {\n    "recipe_id": 1,\n    "tit...
# 3  {"recipe_id":4,"title":"Balsamic Pork Chops","...
# 4  {"recipe_id":1,"title":"Chicken Noodle Soup","...
# 5  ```json\n[\n  {\n    "recipe_id": 1,\n    "tit...
# 6  ```json\n[\n  {\n    "recipe_id": 1,\n    "tit...
# 7  ```json\n[\n  {\n    "recipe_id": 1,\n    "tit...
# 8  ```json\n[\n  {\n    "recipe_id": 1,\n    "tit...
# 9  ```json\n[\n  {\n    "recipe_id": 1,\n    "tit...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Classify each recipe into one of these 8 categ...
# 1  Classify each recipe into one of these 8 categ...
# 2  Classify each recipe into one of these 8 categ...
# 3  Classify each recipe into one of these 8 categ...
# 4  Classify each recipe into one of these 8 categ...
# 5  Classify each recipe into one of these 8 categ...
# 6  Classify each recipe into one of these 8 categ...
# 7  Classify each recipe into one of these 8 categ...
# 8  Classify each recipe into one of these 8 categ...
# 9  Classify each recipe into one of these 8 categ...

# %%
# we misunderstood the fact that the model would be fed one record at a time, after reading the prompt it was given, we can rewrite a better prompt
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Main Dish, Side Dish, Dessert, Drink, Salad, Breakfast, Soup, Appetizer) if it does not aready have a type.  Return the output as json, include the recipe_id, title, and type";
select *
from ML.generate_text(
  model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"recipe_id":1,"title":"Chive Butter Radishes"...
# 1  {"recipe_id":2,"title":"Sweet Potato Breakfast...
# 2  {"recipe_id":3,"title":"Spicy Black Bean Nacho...
# 3  {"recipe_id":4,"title":"Balsamic Pork Chops","...
# 4  {"recipe_id":1,"title":"Chicken Noodle Soup","...
# 5  {"recipe_id":6,"title":"Pinto Beans and Tomati...
# 6  {"recipe_id":7,"title":"Turkey Soup with Homem...
# 7  {"recipe_id":8,"title":"Ham & Potato Soup","ty...
# 8  {"recipe_id":9,"title":"Spanish Chickpeas","ty...
# 9  {"recipe_id":10,"title":"Thai Veggie Soup","ty...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Classify the recipe into one of these types (M...
# 1  Classify the recipe into one of these types (M...
# 2  Classify the recipe into one of these types (M...
# 3  Classify the recipe into one of these types (M...
# 4  Classify the recipe into one of these types (M...
# 5  Classify the recipe into one of these types (M...
# 6  Classify the recipe into one of these types (M...
# 7  Classify the recipe into one of these types (M...
# 8  Classify the recipe into one of these types (M...
# 9  Classify the recipe into one of these types (M...

# %%
# there appear to be lots of soups that are being classified as main dishes. We will try listing main dish last so it recieves less attention and is only used if there is no better cateogry
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Appetizer, Side Dish, Dessert, Drink, Breakfast, Main Dish) if it does not aready have a type. Return the output as json, include the recipe_id, title, and type";
select *
from ML.generate_text(
  model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"recipe_id":1,"title":"Chive Butter Radishes"...
# 1  {"recipe_id":2,"title":"Sweet Potato Breakfast...
# 2  {"recipe_id":3,"title":"Spicy Black Bean Nacho...
# 3  {"recipe_id":4,"title":"Balsamic Pork Chops","...
# 4  {"recipe_id":1,"title":"Creamy Tomato Soup","t...
# 5  {"recipe_id":6,"title":"Pinto Beans and Tomati...
# 6  {"recipe_id":7,"title":"Turkey Soup with Homem...
# 7  {"recipe_id":8,"title":"Ham & Potato Soup","ty...
# 8  {"recipe_id":9,"title":"Spanish Chickpeas","ty...
# 9  {"recipe_id":10,"title":"Thai Veggie Soup","ty...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Classify the recipe into one of these types (S...
# 1  Classify the recipe into one of these types (S...
# 2  Classify the recipe into one of these types (S...
# 3  Classify the recipe into one of these types (S...
# 4  Classify the recipe into one of these types (S...
# 5  Classify the recipe into one of these types (S...
# 6  Classify the recipe into one of these types (S...
# 7  Classify the recipe into one of these types (S...
# 8  Classify the recipe into one of these types (S...
# 9  Classify the recipe into one of these types (S...

# %%
# %%bigquery
# declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Appetizer, Side Dish, Dessert, Drink, Breakfast, Main Dish) if it does not aready have a type. Return the output as json, include the recipe_id, title, and type";
# create or replace table magazine_recipes_stg.type_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#       model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
#     from magazine_recipes_stg.Recipes
#     order by recipe_id
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.recipe_id') as recipe_id,
#   json_value(ml_generate_text_llm_result, '$.type') as type
# from magazine_recipes_stg_ai.type_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   recipe_id       type
# 0         2  Breakfast
# 1         1       Soup
# 2         1  Appetizer
# 3         4  Main Dish
# 4         8       Soup
# 5         6  Main Dish
# 6         9  Main Dish
# 7         3  Appetizer
# 8         7  Main Dish
# 9        10       Soup

# %%
# %%bigquery
# update magazine_recipes_stg.Recipes set type =
#   (select json_value(ml_generate_text_llm_result, '$.type')
#    from  magazine_recipes_stg_ai.type_predictions_raw_10
#    where recipe_id = cast(json_value(ml_generate_text_llm_result, '$.recipe_id') as INT64))
# where type is null
# Out:
# Executing query with job ID: 90c6a310-d141-4217-a00a-7816beeb6d51
# Query executing: 0.56s
# ERROR:
#  400 Scalar subquery produced more than one element
#
# Location: US
# Job ID: 90c6a310-d141-4217-a00a-7816beeb6d51

# %%
# The model got confused for records that already had a type, which resulted in non-unique recipe_id. We will try to clarify the prompt and see if recipe_id will be unique
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Appetizer, Side Dish, Dessert, Drink, Breakfast, Main Dish) if it does not aready have a type. If it does have a type, assign the type listed. Return the output as json, include the recipe_id, title, and type";
select *
from ML.generate_text(
  model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"recipe_id":1,"title":"Chive Butter Radishes"...
# 1  {"recipe_id":2,"title":"Sweet Potato Breakfast...
# 2  {"recipe_id":3,"title":"Spicy Black Bean Nacho...
# 3  {"recipe_id":4,"title":"Balsamic Pork Chops","...
# 4  {"recipe_id":1,"title":"Creamy Tomato Soup","t...
# 5  {"recipe_id":6,"title":"Pinto Beans and Tomati...
# 6  {"recipe_id":7,"title":"Turkey Soup with Homem...
# 7  {"recipe_id":8,"title":"Ham & Potato Soup","ty...
# 8  {"recipe_id":9,"title":"Spanish Chickpeas","ty...
# 9  {"recipe_id":10,"title":"Thai Veggie Soup","ty...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Classify the recipe into one of these types (S...
# 1  Classify the recipe into one of these types (S...
# 2  Classify the recipe into one of these types (S...
# 3  Classify the recipe into one of these types (S...
# 4  Classify the recipe into one of these types (S...
# 5  Classify the recipe into one of these types (S...
# 6  Classify the recipe into one of these types (S...
# 7  Classify the recipe into one of these types (S...
# 8  Classify the recipe into one of these types (S...
# 9  Classify the recipe into one of these types (S...

# %%
# This clarification did not work, let us try omitting the information about existing types
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Appetizer, Side Dish, Dessert, Drink, Breakfast, Main Dish) Return the output as json, include the recipe_id, title, and type";
select *
from ML.generate_text(
  model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"recipe_id":1,"title":"Chive Butter Radishes"...
# 1  {"recipe_id":2,"title":"Sweet Potato Breakfast...
# 2  {"recipe_id":3,"title":"Spicy Black Bean Nacho...
# 3  {"recipe_id":4,"title":"Balsamic Pork Chops","...
# 4  {"recipe_id":5,"title":"Chocolate Raspberry To...
# 5  {"recipe_id":6,"title":"Pinto Beans and Tomati...
# 6  {"recipe_id":7,"title":"Turkey Soup with Homem...
# 7  {"recipe_id":8,"title":"Ham & Potato Soup","ty...
# 8  {"recipe_id":9,"title":"Spanish Chickpeas","ty...
# 9  {"recipe_id":10,"title":"Thai Veggie Soup","ty...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Classify the recipe into one of these types (S...
# 1  Classify the recipe into one of these types (S...
# 2  Classify the recipe into one of these types (S...
# 3  Classify the recipe into one of these types (S...
# 4  Classify the recipe into one of these types (S...
# 5  Classify the recipe into one of these types (S...
# 6  Classify the recipe into one of these types (S...
# 7  Classify the recipe into one of these types (S...
# 8  Classify the recipe into one of these types (S...
# 9  Classify the recipe into one of these types (S...

# %%
# We have unique recipe_id now, but breakfast tacos are now a main dish. Let us give more explicit instructions about main dish and see if it helps
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Appetizer, Side Dish, Dessert, Drink, Breakfast, Main Dish). Only assign main dish if it does not fit into one of the more precise types. Return the output as json, include the recipe_id, title, and type";
select *
from ML.generate_text(
  model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"recipe_id":1,"title":"Chive Butter Radishes"...
# 1  {"recipe_id":2,"title":"Sweet Potato Breakfast...
# 2  {"recipe_id":3,"title":"Spicy Black Bean Nacho...
# 3  {"recipe_id":4,"title":"Balsamic Pork Chops","...
# 4  {"recipe_id":5,"title":"Chocolate Raspberry To...
# 5  {"recipe_id":6,"title":"Pinto Beans and Tomati...
# 6  {"recipe_id":7,"title":"Turkey Soup with Homem...
# 7  {"recipe_id":8,"title":"Ham & Potato Soup","ty...
# 8  {"recipe_id":9,"title":"Spanish Chickpeas","ty...
# 9  {"recipe_id":10,"title":"Thai Veggie Soup","ty...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Classify the recipe into one of these types (S...
# 1  Classify the recipe into one of these types (S...
# 2  Classify the recipe into one of these types (S...
# 3  Classify the recipe into one of these types (S...
# 4  Classify the recipe into one of these types (S...
# 5  Classify the recipe into one of these types (S...
# 6  Classify the recipe into one of these types (S...
# 7  Classify the recipe into one of these types (S...
# 8  Classify the recipe into one of these types (S...
# 9  Classify the recipe into one of these types (S...

# %%
# Breakfast tacos were still classified as main dish, let us try another clarification
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Dessert, Breakfast, Appetizer, Drink, Side Dish, Main Dish). Evaluate if it can be classified as one of the types in the order they are listed. If the type is in the title, assign that as the type. Return the output as json, include the recipe_id, title, and type";
select *
from ML.generate_text(
  model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"recipe_id":1,"title":"Chive Butter Radishes"...
# 1  {"recipe_id":2,"title":"Sweet Potato Breakfast...
# 2  {"recipe_id":3,"title":"Spicy Black Bean Nacho...
# 3  {"recipe_id":4,"title":"Balsamic Pork Chops","...
# 4  {"recipe_id":5,"title":"Chocolate Raspberry To...
# 5  {"recipe_id":6,"title":"Pinto Beans and Tomati...
# 6  {"recipe_id":7,"title":"Turkey Soup with Homem...
# 7  {"recipe_id":8,"title":"Ham & Potato Soup","ty...
# 8  {"recipe_id":9,"title":"Spanish Chickpeas","ty...
# 9  {"recipe_id":10,"title":"Thai Veggie Soup","ty...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Classify the recipe into one of these types (S...
# 1  Classify the recipe into one of these types (S...
# 2  Classify the recipe into one of these types (S...
# 3  Classify the recipe into one of these types (S...
# 4  Classify the recipe into one of these types (S...
# 5  Classify the recipe into one of these types (S...
# 6  Classify the recipe into one of these types (S...
# 7  Classify the recipe into one of these types (S...
# 8  Classify the recipe into one of these types (S...
# 9  Classify the recipe into one of these types (S...

# %%
# We are happy with the classifications and can update the table in BQ
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Dessert, Breakfast, Appetizer, Drink, Side Dish, Main Dish). Evaluate if it can be classified as one of the types in the order they are listed. If the type is in the title, assign that as the type. Return the output as json, include the recipe_id, title, and type";
create or replace table magazine_recipes_stg_ai.type_predictions_raw_10 as
  select *
  from ML.generate_text(
      model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.recipe_id') as recipe_id,
#   json_value(ml_generate_text_llm_result, '$.title') as title,
#   json_value(ml_generate_text_llm_result, '$.type') as type
# from magazine_recipes_stg_ai.type_predictions_raw_10
# order by recipe_id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   recipe_id                                         title       type
# 0         1                         Chive Butter Radishes  Appetizer
# 1        10                              Thai Veggie Soup       Soup
# 2         2               Sweet Potato Breakfast Burritos  Breakfast
# 3         3                       Spicy Black Bean Nachos  Main Dish
# 4         4                           Balsamic Pork Chops  Main Dish
# 5         5                     Chocolate Raspberry Torte    Dessert
# 6         6  Pinto Beans and Tomatillo Cilantro Lime Rice  Main Dish
# 7         7             Turkey Soup with Homemade Noodles  Main Dish
# 8         8                             Ham & Potato Soup       Soup
# 9         9                             Spanish Chickpeas  Main Dish

# %%
# Update the recipes table
# %%bigquery
update magazine_recipes_stg.Recipes set type =
  (select json_value(ml_generate_text_llm_result, '$.type')
   from magazine_recipes_stg_ai.type_predictions_raw_10
   where recipe_id = cast(json_value(ml_generate_text_llm_result, '$.recipe_id') as int64))
where 1 = 1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Inspect the output

# %%
# check the output- subset by recipe_id since many other records already have non-AI generated types
# %%bigquery
select *
from magazine_recipes_stg.Recipes
where type is not null and recipe_id < 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    recipe_id                                         title subtitle  servings  \
# 0          4                           Balsamic Pork Chops     None      <NA>
# 1          3                       Spicy Black Bean Nachos     None      <NA>
# 2          2               Sweet Potato Breakfast Burritos     None      <NA>
# 3          1                         Chive Butter Radishes     None      <NA>
# 4          9                             Spanish Chickpeas     None      <NA>
# 5          5                     Chocolate Raspberry Torte     None      <NA>
# 6          8                             Ham & Potato Soup     None      <NA>
# 7          6  Pinto Beans and Tomatillo Cilantro Lime Rice     None      <NA>
# 8          7             Turkey Soup with Homemade Noodles     None      <NA>
#
#   yield_unit  prep_min  cook_min  stnd_min source intro  ... rating  \
# 0       None      <NA>      <NA>      <NA>   None  None  ...      1
# 1       None      <NA>      <NA>      <NA>   None  None  ...      2
# 2       None      <NA>      <NA>      <NA>   None  None  ...      4
# 3       None      <NA>      <NA>      <NA>   None  None  ...      4
# 4       None        45      <NA>      <NA>   None  None  ...      5
# 5       None        60      <NA>      <NA>   None  None  ...      5
# 6       None        60      <NA>      <NA>   None  None  ...      4
# 7       None        60      <NA>      <NA>   None  None  ...      5
# 8       None       120      <NA>      <NA>   None  None  ...      4
#
#    ease_of_prep                                           note       type  \
# 0          None                                           None  Main Dish
# 1          None                                           None  Main Dish
# 2          None                                           None  Breakfast
# 3          None                                           None  Appetizer
# 4       Average  Don't forget to make Naan dough ahead of time  Main Dish
# 5          Hard                                        So good    Dessert
# 6       Average                                    Super yummy       Soup
# 7          Hard                                 Amazing flavor  Main Dish
# 8       Average                                           None  Main Dish
#
#    page  slowcooker                                               link  \
# 0  <NA>        None                                               None
# 1  <NA>        None  https://www.mexicanplease.com/spicy-black-bean...
# 2  <NA>        None  https://www.ambitiouskitchen.com/healthy-sweet...
# 3  <NA>        None                                               None
# 4  <NA>        None  https://www.prevention.com/food/10-healthy-chi...
# 5  <NA>        None                                               None
# 6  <NA>        None  http://allrecipes.com/recipe/56927/delicious-h...
# 7  <NA>        None  https://www.thecuriouschickpea.com/mexican-pin...
# 8  <NA>        None                                               None
#
#     last_made data_source                        load_time
# 0  2019-02-14    airtable 2024-02-02 21:09:57.475069+00:00
# 1  2018-09-17    airtable 2024-02-02 21:09:57.475069+00:00
# 2  2018-11-01    airtable 2024-02-02 21:09:57.475069+00:00
# 3  2018-06-16    airtable 2024-02-02 21:09:57.475069+00:00
# 4  2019-01-21    airtable 2024-02-02 21:09:57.475069+00:00
# 5  2016-10-11    airtable 2024-02-02 21:09:57.475069+00:00
# 6  2018-07-15    airtable 2024-02-02 21:09:57.475069+00:00
# 7  2019-02-17    airtable 2024-02-02 21:09:57.475069+00:00
# 8  2016-11-17    airtable 2024-02-02 21:09:57.475069+00:00
#
# [9 rows x 21 columns]

# %% [markdown]
# #### Apply at larger scale

# %%
# We do not have to reformat the json, so no need to name the table raw since it will be the final one
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Dessert, Breakfast, Appetizer, Drink, Side Dish, Main Dish). Evaluate if it can be classified as one of the types in the order they are listed. If the type is in the title, assign that as the type. Return the output as json, include the recipe_id, title, and type";
create or replace table magazine_recipes_stg_ai.type_predictions as
  select *
  from ML.generate_text(
      model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Query only took 5 minutes to run since there were under 1000 recipes in the table

# %%
# %%bigquery
# update magazine_recipes_stg.Recipes r
#   set type = json_value(p.ml_generate_text_llm_result, '$.type')
#   from magazine_recipes_stg_ai.type_predictions p
#   where r.recipe_id = cast(json_value(p.ml_generate_text_llm_result, '$.recipe_id') as int64);
# Out:
# Executing query with job ID: 676e4d64-a069-494d-859f-781f0b1d4183
# Query executing: 0.22s
# ERROR:
#  400 Syntax error: Expected end of input but got keyword WHERE at [5:1]
#
# Location: US
# Job ID: 676e4d64-a069-494d-859f-781f0b1d4183

# %%
# check to see if we are missing any types
# %%bigquery
select count(*) as missing_types
from magazine_recipes_stg.Recipes
where type is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    type_count
# 0         307

# %%
# %%bigquery
# select * from magazine_recipes_stg.Recipes
# where type is null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    recipe_id                       title subtitle  servings yield_unit  \
# 0         43          Potato Apple Roast     None      <NA>       None
# 1        142        Dill Cucumber Salmon     None      <NA>       None
# 2        117            Cloverleaf Rolls     None      <NA>       None
# 3         45            Malteese Gilatti     None      <NA>       None
# 4         61  Buckwheat Carrot and Onion     None      <NA>       None
#
#    prep_min  cook_min  stnd_min             source intro  ... rating  \
# 0        45      <NA>      <NA>          Pinterest  None  ...      4
# 1        30      <NA>      <NA>  Sheet Pan Suppers  None  ...      4
# 2        30      <NA>      <NA>    Taste From Home  None  ...      3
# 3       120      <NA>      <NA>          Pinterest  None  ...      2
# 4        40      <NA>      <NA>          Pinterest  None  ...      4
#
#    ease_of_prep                     note  type  page  slowcooker  \
# 0       Average                     None  None  <NA>        None
# 1       Average                     None  None  <NA>        None
# 2   Fairly Easy                     None  None  <NA>        None
# 3       Average  Hard to get them toasty  None  <NA>        None
# 4   Fairly Easy                     None  None  <NA>        None
#
#                                                 link   last_made data_source  \
# 0  https://www.healthyseasonalrecipes.com/roasted...  2018-07-21    airtable
# 1                                               None  2018-11-02    airtable
# 2                                               None         NaT    airtable
# 3  http://www.ilovefood.com.mt/recipes/galletti-r...  2017-12-17    airtable
# 4  http://www.pinchofcinnamon.com/2011/12/cooking...  2018-01-10    airtable
#
#                          load_time
# 0 2024-02-02 21:09:57.475069+00:00
# 1 2024-02-02 21:09:57.475069+00:00
# 2 2024-02-02 21:09:57.475069+00:00
# 3 2024-02-02 21:09:57.475069+00:00
# 4 2024-02-02 21:09:57.475069+00:00
#
# [5 rows x 21 columns]

# %%
# Add direction telling the model to assign a type to every recipe
# %%bigquery
declare prompt_query STRING default "Classify the recipe into one of these types (Soup, Salad, Dessert, Breakfast, Appetizer, Drink, Side Dish, Main Dish). Do not return a null type. Evaluate if it can be classified as one of the types in the order they are listed. If the type is in the title, assign that as the type. Return the output as json, include the recipe_id, title, and type";
create or replace table magazine_recipes_stg_ai.type_predictions as
  select *
  from ML.generate_text(
      model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", recipe_id, "title", title, "type", type))) as prompt
    from magazine_recipes_stg.Recipes
    order by recipe_id
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update magazine_recipes_stg.Recipes r
#   set type = json_value(p.ml_generate_text_llm_result, '$.type')
#   from magazine_recipes_stg_ai.type_predictions p
#   where r.recipe_id = cast(json_value(p.ml_generate_text_llm_result, '$.recipe_id') as int64);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# check to see if we are missing any types
# %%bigquery
select count(*) as missing_types
from magazine_recipes_stg.Recipes
where type is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    missing_types
# 0              0

# %%
# note that the model added a few categories such as Miscellaneous and dressings
# %%bigquery
select type, count(*) as type_count
from magazine_recipes_stg.Recipes
group by type
order by type_count desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#              type  type_count
# 0       Main Dish         367
# 1   Miscellaneous         187
# 2           Salad         130
# 3         Dessert         106
# 4       Side Dish          74
# 5            Soup          46
# 6           Drink          40
# 7       Appetizer          34
# 8       Breakfast          34
# 9        Dressing           4
# 10          Sauce           1

# %%
# since there is only one recipe that is a sauce and 4 dressings, we will combine them into one category
# %%bigquery
update magazine_recipes_stg.Recipes
  set type = 'Dressing/Sauce'
where type in ('Dressing', 'Sauce')
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select type, count(*) as type_count
# from magazine_recipes_stg.Recipes
# group by type
# order by type_count desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#              type  type_count
# 0       Main Dish         367
# 1   Miscellaneous         187
# 2           Salad         130
# 3         Dessert         106
# 4       Side Dish          74
# 5            Soup          46
# 6           Drink          40
# 7       Appetizer          34
# 8       Breakfast          34
# 9  Dressing/Sauce           5

# %%
# we will not update the datasource because the type will be present in the pages table and not in the recipes table

# %% [markdown]
# ## Clean ingredients table
# Initally we planned to use AI to give categories to airtable ingredients not found in bird, but we realized that the ingredients were likely already in bird but under a slightly different name, we will use the next section to clean up the ingredients table before continuing on with project 9

# %%
# %%bigquery
# select * from magazine_recipes_stg.Ingredients
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    ingredient_id category             name plural data_source  \
# 0           4648     None          carrots   None    Airtable
# 1           4666     None      adobo chile   None    Airtable
# 2           4661     None            beets   None    Airtable
# 3           4655     None       vegetarian   None    Airtable
# 4           4660     None             kale   None    Airtable
# 5           4656     None         potatoes   None    Airtable
# 6           4658     None  chocolate chips   None    Airtable
# 7           4646     None      bell pepper   None    Airtable
# 8           4663     None         parsnips   None    Airtable
# 9           4653     None          gnocchi   None    Airtable
#
#                          load_time
# 0 2024-02-02 21:09:57.475069+00:00
# 1 2024-02-02 21:09:57.475069+00:00
# 2 2024-02-02 21:09:57.475069+00:00
# 3 2024-02-02 21:09:57.475069+00:00
# 4 2024-02-02 21:09:57.475069+00:00
# 5 2024-02-02 21:09:57.475069+00:00
# 6 2024-02-02 21:09:57.475069+00:00
# 7 2024-02-02 21:09:57.475069+00:00
# 8 2024-02-02 21:09:57.475069+00:00
# 9 2024-02-02 21:09:57.475069+00:00

# %%
# oh no! It appears we forgot to account for plurals when we merged the airtable and bird ingreidient tables :( lets remedy this!
# %%bigquery
select * from magazine_recipes_stg.Ingredients
where name = 'carrot'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    ingredient_id          category    name plural data_source  \
# 0           2260  fresh vegetables  carrot      s        bird
#
#                          load_time
# 0 2024-01-26 23:50:31.637778+00:00

# %%
# %%bigquery
# select *
# from magazine_recipes_stg.Ingredients
# where ENDS_WITH(name, 's') = True and data_source = 'Airtable'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    ingredient_id category              name plural data_source  \
# 0           4648     None           carrots   None    Airtable
# 1           4661     None             beets   None    Airtable
# 2           4656     None          potatoes   None    Airtable
# 3           4658     None   chocolate chips   None    Airtable
# 4           4663     None          parsnips   None    Airtable
# 5           4662     None          tomatoes   None    Airtable
# 6           4664     None              eggs   None    Airtable
# 7           4657     None       breadcrumbs   None    Airtable
# 8           4649     None  brussels sprouts   None    Airtable
# 9           4651     None          shallots   None    Airtable
#
#                          load_time
# 0 2024-02-02 21:09:57.475069+00:00
# 1 2024-02-02 21:09:57.475069+00:00
# 2 2024-02-02 21:09:57.475069+00:00
# 3 2024-02-02 21:09:57.475069+00:00
# 4 2024-02-02 21:09:57.475069+00:00
# 5 2024-02-02 21:09:57.475069+00:00
# 6 2024-02-02 21:09:57.475069+00:00
# 7 2024-02-02 21:09:57.475069+00:00
# 8 2024-02-02 21:09:57.475069+00:00
# 9 2024-02-02 21:09:57.475069+00:00

# %%
# %%bigquery
# create or replace table magazine_recipes_stg.Ingredients_duplicates as
# select * from
# ((select ingredient_id as wrong_id, LEFT(name, LENGTH(name) - 1) as at_name
# from magazine_recipes_stg.Ingredients
# where ENDS_WITH(name, 's') = True
# and data_source = 'Airtable'
# and LEFT(name, LENGTH(name) - 1) in (select name from magazine_recipes_stg.Ingredients where data_source = 'bird'))
# UNION ALL
# (select ingredient_id as wrong_id, LEFT(name, LENGTH(name) - 2) at_name
# from magazine_recipes_stg.Ingredients
# where ENDS_WITH(name, 's') = True
# and data_source = 'Airtable'
# and LEFT(name, LENGTH(name) - 2) in (select name from magazine_recipes_stg.Ingredients where data_source = 'bird'))) a
# left join (select name, ingredient_id from magazine_recipes_stg.Ingredients) b on a.at_name = b.name
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from magazine_recipes_stg.Ingredients_duplicates
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    wrong_id         at_name            name  ingredient_id
# 0      4656          potato          potato           2286
# 1      4662          tomato          tomato           3480
# 2      4661            beet            beet            199
# 3      4651         shallot         shallot           3093
# 4      4648          carrot          carrot           2260
# 5      4663         parsnip         parsnip           2534
# 6      4664             egg             egg           1171
# 7      4658  chocolate chip  chocolate chip            707

# %%
# now we have this table of the old and new ingredient ids for the duplicate ingredients that we can use to update the junction table before we delete the incorrect records from ingredients
# %%bigquery
update magazine_recipes_stg.Quantity
set ingredient_id = (select ingredient_id from magazine_recipes_stg.Ingredients_duplicates where wrong_id = ingredient_id)
where ingredient_id in (select wrong_id from magazine_recipes_stg.Ingredients_duplicates)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# check if the updates worked in junction table
# %%bigquery
select count(*) as wrong_ids from magazine_recipes_stg.Quantity
where ingredient_id in (select wrong_id from magazine_recipes_stg.Ingredients_duplicates)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    wrong_ids
# 0          0

# %%
# delete the duplicate records from ingredients
# %%bigquery
delete from magazine_recipes_stg.Ingredients
where ingredient_id in (select wrong_id from magazine_recipes_stg.Ingredients_duplicates)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# update the datasource for those ingreidents
# %%bigquery
update magazine_recipes_stg.Ingredients
set data_source = 'bird-airtable'
where ingredient_id in (select wrong_id from magazine_recipes_stg.Ingredients_duplicates)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# it appears that these are likely in bird but labeled slighly differenly, since there are only 15, we will go in by hand and edit them
# %%bigquery
select * from magazine_recipes_stg.Ingredients
where data_source = 'Airtable'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     ingredient_id category              name plural data_source  \
# 0            4668     None            peanut   None    Airtable
# 1            4657     None       breadcrumbs   None    Airtable
# 2            4665     None              wine   None    Airtable
# 3            4649     None  brussels sprouts   None    Airtable
# 4            4654     None   jalopeno pepper   None    Airtable
# 5            4647     None           tilapia   None    Airtable
# 6            4666     None       adobo chile   None    Airtable
# 7            4659     None              chia   None    Airtable
# 8            4653     None           gnocchi   None    Airtable
# 9            4667     None              tuna   None    Airtable
# 10           4646     None       bell pepper   None    Airtable
# 11           4652     None           chicken   None    Airtable
# 12           4660     None              kale   None    Airtable
# 13           4650     None     dijon mustard   None    Airtable
# 14           4655     None        vegetarian   None    Airtable
#
#                           load_time
# 0  2024-02-02 21:09:57.475069+00:00
# 1  2024-02-02 21:09:57.475069+00:00
# 2  2024-02-02 21:09:57.475069+00:00
# 3  2024-02-02 21:09:57.475069+00:00
# 4  2024-02-02 21:09:57.475069+00:00
# 5  2024-02-02 21:09:57.475069+00:00
# 6  2024-02-02 21:09:57.475069+00:00
# 7  2024-02-02 21:09:57.475069+00:00
# 8  2024-02-02 21:09:57.475069+00:00
# 9  2024-02-02 21:09:57.475069+00:00
# 10 2024-02-02 21:09:57.475069+00:00
# 11 2024-02-02 21:09:57.475069+00:00
# 12 2024-02-02 21:09:57.475069+00:00
# 13 2024-02-02 21:09:57.475069+00:00
# 14 2024-02-02 21:09:57.475069+00:00

# %%
# %%bigquery
# update magazine_recipes_stg.Quantity
# set ingredient_id = 1025
# where ingredient_id = 4650
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update magazine_recipes_stg.Ingredients
# set data_source = 'bird_airtable'
# where ingredient_id = 1025
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# delete from magazine_recipes_stg.Ingredients
# where ingredient_id = 4650
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from magazine_recipes_stg.Ingredients
# where CONTAINS_SUBSTR(name, 'dijon') = True
# order by ingredient_id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    ingredient_id           category                                      name  \
# 0            763  condiments/sauces                coarse Dijon-style mustard
# 1            896  condiments/sauces               country-style Dijon mustard
# 2           1025  condiments/sauces                             Dijon mustard
# 3           3778    salad dressings  Wish-Bone Healthy Sensation! Honey Dijon
# 4           4650               None                             dijon mustard
#
#   plural data_source                        load_time
# 0   None        bird 2024-01-26 23:50:31.637778+00:00
# 1   None        bird 2024-01-26 23:50:31.637778+00:00
# 2   None        bird 2024-01-26 23:50:31.637778+00:00
# 3   None        bird 2024-01-26 23:50:31.637778+00:00
# 4   None    Airtable 2024-02-02 21:09:57.475069+00:00

# %%
# make sure we don't have any orphans in quantity, we don't yay!
# %%bigquery
select count(*) as orphans from magazine_recipes_stg.Quantity
where ingredient_id not in (select ingredient_id from magazine_recipes_stg.Ingredients)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphans
# 0        0

# %% [markdown]
# # Change 2: Create User names based on First Name Last Name, State, and fun persona

# %%
# assign usernames to the users table
# %%bigquery
declare prompt_query STRING default "Assign a user name for a recipe sharing platform based on user data and other fun terms commonly found in usernames or related to cooking. Only include numbers and letters in usernames. Get creative and have fun with it. Return the output as json, include the numeric user_id, first name, and last name and creative user name";
  select *
  from ML.generate_text(
      model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("user_id", user_id, "first_name", f_name, "last_name", l_name, "age", age))) as prompt
    from magazine_recipes_stg.Users
    order by user_id
    limit 10
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"user_id":1,"first_name":"Norma","last_name":...
# 1  ```json\n{\n  "user_id": 2,\n  "first_name": "...
# 2  {"user_id":3,"first_name":"Beyonce","last_name...
# 3  ```json\n{\n  "user_id": 4,\n  "first_name": "...
# 4  ```json\n{\n  "user_id": 5,\n  "first_name": "...
# 5  ```json\n{\n  "user_id": 6,\n  "first_name": "...
# 6  {"user_id":7,"first_name":"Samantha","last_nam...
# 7  ```json\n{\n  "user_id": 8,\n  "first_name": "...
# 8  {"user_id":9,"first_name":"Lisa","last_name":"...
# 9  ```json\n{\n  "user_id": 10,\n  "first_name": ...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Assign a user name for a recipe sharing platfo...
# 1  Assign a user name for a recipe sharing platfo...
# 2  Assign a user name for a recipe sharing platfo...
# 3  Assign a user name for a recipe sharing platfo...
# 4  Assign a user name for a recipe sharing platfo...
# 5  Assign a user name for a recipe sharing platfo...
# 6  Assign a user name for a recipe sharing platfo...
# 7  Assign a user name for a recipe sharing platfo...
# 8  Assign a user name for a recipe sharing platfo...
# 9  Assign a user name for a recipe sharing platfo...

# %%
# %%bigquery
# alter table magazine_recipes_stg.Users add column username String;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# apply at larger scale
# %%bigquery
declare prompt_query STRING default "Assign a user name for a recipe sharing platform based on user data and other fun terms commonly found in usernames or related to cooking. Only include numbers and letters in usernames. Get creative and have fun with it. Return the output as json, include the numeric user_id, first name, and last name and creative user name";
  create or replace table magazine_recipes_stg_ai.usernames as
  select *
  from ML.generate_text(
      model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("user_id", user_id, "first_name", f_name, "last_name", l_name, "age", age))) as prompt
    from magazine_recipes_stg.Users
    order by user_id
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from magazine_recipes_stg_ai.usernames
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "user_id": 13,\n  "first_name": ...
# 1  ```json\n{\n  "user_id": 25,\n  "first_name": ...
# 2  {"user_id":54,"first_name":"Janice","last_name...
# 3  ```json\n{\n  "user_id": 63,\n  "first_name": ...
# 4  ```json\n{\n  "user_id": 75,\n  "first_name": ...
# 5  ```json\n{\n  "user_id": 28,\n  "first_name": ...
# 6  ```json\n{\n  "user_id": 45,\n  "first_name": ...
# 7  {"age":47,"first_name":"Sarah","last_name":"La...
# 8  {"age":36,"first_name":"Eric","last_name":"Pri...
# 9  ```json\n{\n  "user_id": 10,\n  "first_name": ...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Assign a user name for a recipe sharing platfo...
# 1  Assign a user name for a recipe sharing platfo...
# 2  Assign a user name for a recipe sharing platfo...
# 3  Assign a user name for a recipe sharing platfo...
# 4  Assign a user name for a recipe sharing platfo...
# 5  Assign a user name for a recipe sharing platfo...
# 6  Assign a user name for a recipe sharing platfo...
# 7  Assign a user name for a recipe sharing platfo...
# 8  Assign a user name for a recipe sharing platfo...
# 9  Assign a user name for a recipe sharing platfo...

# %%
# %%bigquery
# update magazine_recipes_stg.Users set username =
#   (select json_value(ml_generate_text_llm_result, '$.user_name')
#    from magazine_recipes_stg_ai.usernames
#    where user_id = CAST(json_value(ml_generate_text_llm_result, '$.user_id') as INT64))
# where 1=1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_stg.Users
# where username is NULL
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0   64

# %%
# some json fields are named username rather than user_name
# %%bigquery
update magazine_recipes_stg.Users set username =
  (select json_value(ml_generate_text_llm_result, '$.username')
   from magazine_recipes_stg_ai.usernames
   where user_id = CAST(json_value(ml_generate_text_llm_result, '$.user_id') as INT64))
where username is null;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_stg.Users
# where username is NULL
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0   47

# %%
# I will just re-ask ai and specify what the new field should be called so that there are no nulls
# %%bigquery
declare prompt_query STRING default "Assign a user name for a recipe sharing platform based on user data and other fun terms commonly found in usernames or related to cooking. Only include numbers and letters in usernames. Get creative and have fun with it. Return the output as json, include the numeric user_id, first name, and last name and creative user name (named the json field user_name)";
  create or replace table magazine_recipes_stg_ai.usernames as
  select *
  from ML.generate_text(
      model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("user_id", user_id, "first_name", f_name, "last_name", l_name, "age", age))) as prompt
    from magazine_recipes_stg.Users
    order by user_id
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update magazine_recipes_stg.Users set username =
#   (select json_value(ml_generate_text_llm_result, '$.user_name')
#    from magazine_recipes_stg_ai.usernames
#    where user_id = CAST(json_value(ml_generate_text_llm_result, '$.user_id') as INT64))
# where 1=1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_stg.Users
# where username is NULL
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0    0

# %%
# update the datasource for users
# %%bigquery
create or replace table magazine_recipes_stg.Users as
select user_id, username, f_name, l_name, age, phone, state, 'faker-ai' as data_source, load_time
from magazine_recipes_stg.Users
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from magazine_recipes_stg.Publications
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    publication_id  recipe_id  magazine_id  journalist_id date  volume  issue  \
# 0               0       1471            7             38  NaT    <NA>   <NA>
# 1               1       1559           17             17  NaT    <NA>   <NA>
# 2               2       1509           14             25  NaT    <NA>   <NA>
# 3               3       1458            4             81  NaT    <NA>   <NA>
# 4               4       1567           17             29  NaT    <NA>   <NA>
#
#   publication_type data_source                        load_time
# 0             None        None 2024-02-10 01:05:38.042312+00:00
# 1             None        None 2024-02-10 01:05:38.042312+00:00
# 2             None        None 2024-02-10 01:05:38.042312+00:00
# 3             None        None 2024-02-10 01:05:38.042312+00:00
# 4             None        None 2024-02-10 01:05:38.042312+00:00

# %%
# since we are no longer doing magazines, we must change the publications table to posts
# %%bigquery
create or replace table magazine_recipes_stg.Posts as
select p.publication_id as post_id, p.recipe_id, p.journalist_id as user_id, r.type as page, TIMESTAMP_SUB(p.load_time, INTERVAL CAST(FLOOR(RAND() * 2000) AS INT64) DAY) as timestamp_posted, 'ai' as datasource, p.load_time as load_time
from magazine_recipes_stg.Publications p
join magazine_recipes_stg.Recipes r
on p.recipe_id = r.recipe_id
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from magazine_recipes_stg.Posts
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    post_id  recipe_id  user_id  page                 timestamp_posted  \
# 0     1073        139        1  Soup 2020-05-17 01:05:38.042312+00:00
# 1      641       1187        5  Soup 2021-10-04 01:05:38.042312+00:00
# 2     1056         68        5  Soup 2021-11-20 01:05:38.042312+00:00
# 3     1004        557        9  Soup 2022-12-02 01:05:38.042312+00:00
# 4      969         10       16  Soup 2019-01-28 01:05:38.042312+00:00
#
#   datasource                        load_time
# 0         ai 2024-02-10 01:05:38.042312+00:00
# 1         ai 2024-02-10 01:05:38.042312+00:00
# 2         ai 2024-02-10 01:05:38.042312+00:00
# 3         ai 2024-02-10 01:05:38.042312+00:00
# 4         ai 2024-02-10 01:05:38.042312+00:00

# %%
# remove the type field from recipes because it is now in posts
# %%bigquery
create or replace table magazine_recipes_stg.Recipes as
select * except(type)
from magazine_recipes_stg.Recipes
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Change 3:  Use AI to add a health rating to the nutrition table based on Nutritional value

# %%
# %%bigquery
# declare prompt_query STRING default "Rate the nutritional value of the recipe from 1-5. 1 being unhealthy and 5 being healthy. Return output as json with recipe_id ";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("recipe_id", n.recipe_id, "title", title,
#                   "carbo", carbo, "total_fat", total_fat, "cholestrl", cholestrl, "sodium", sodium, "calories",calories, "iron", iron, "vitamin_c", vitamin_c, "vitamin_a", vitamin_a))) as prompt
#     from magazine_recipes_stg.Nutrition n
#     inner join magazine_recipes_stg.Recipes r on r.recipe_id = n.recipe_id
#     limit 20
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                           ml_generate_text_llm_result  \
# 0   ```json\n{\n  "recipe_id": 895,\n  "calories":...
# 1   ```json\n{"calories":16.64,"carbo":4.16,"chole...
# 2   ```json\n{\n  "calories": 15.75,\n  "carbo": 2...
# 3   ```json\n{\n  "recipe_id": 1172,\n  "calories"...
# 4   ```json\n{\n  "calories": 139.13,\n  "carbo": ...
# 5   ```json\n{\n  "recipe_id": 916,\n  "calories":...
# 6   ```json\n{\n  "recipe_id": 1084,\n  "calories"...
# 7   ```json\n{\n  "recipe_id": 1346,\n  "title": "...
# 8   ```json\n{\n  "recipe_id": 586,\n  "rating": 3...
# 9   ```json\n{\n  "recipe_id": 819,\n  "nutritiona...
# 10  ```json\n{\n  "recipe_id": 1120,\n  "title": "...
# 11  ```json\n{\n  "recipe_id": 917,\n  "title": "-...
# 12  ```json\n{\n  "recipe_id": 1057,\n  "title": "...
# 13  ```json\n{\n  "recipe_id": 1073,\n  "nutrition...
# 14  ```json\n{\n  "recipe_id": 477,\n  "nutritiona...
# 15  ```json\n{\n  "recipe_id": 1198,\n  "calories"...
# 16  ```json\n{\n  "recipe_id": 584,\n  "nutritiona...
# 17  ```json\n{\n  "recipe_id": 1162,\n  "calories"...
# 18  ```json\n{\n  "recipe_id": 1133,\n  "title": "...
# 19  ```json\n{\n  "recipe_id": 1159,\n  "nutrition...
#
#    ml_generate_text_rai_result ml_generate_text_status  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6                         None
# 7                         None
# 8                         None
# 9                         None
# 10                        None
# 11                        None
# 12                        None
# 13                        None
# 14                        None
# 15                        None
# 16                        None
# 17                        None
# 18                        None
# 19                        None
#
#                                                prompt
# 0   Rate the nutritional value of the recipe from ...
# 1   Rate the nutritional value of the recipe from ...
# 2   Rate the nutritional value of the recipe from ...
# 3   Rate the nutritional value of the recipe from ...
# 4   Rate the nutritional value of the recipe from ...
# 5   Rate the nutritional value of the recipe from ...
# 6   Rate the nutritional value of the recipe from ...
# 7   Rate the nutritional value of the recipe from ...
# 8   Rate the nutritional value of the recipe from ...
# 9   Rate the nutritional value of the recipe from ...
# 10  Rate the nutritional value of the recipe from ...
# 11  Rate the nutritional value of the recipe from ...
# 12  Rate the nutritional value of the recipe from ...
# 13  Rate the nutritional value of the recipe from ...
# 14  Rate the nutritional value of the recipe from ...
# 15  Rate the nutritional value of the recipe from ...
# 16  Rate the nutritional value of the recipe from ...
# 17  Rate the nutritional value of the recipe from ...
# 18  Rate the nutritional value of the recipe from ...
# 19  Rate the nutritional value of the recipe from ...

# %%
# None of the recipes were being rated 1 or 5. THey were all mostly 3 or 3, so we narrow the ratings down further.
# %%bigquery
declare prompt_query STRING default "Rate the nutritional value as: 1,2 or 3. 1 being unhealthy, 2 being neutral, and 3 being  healthy. Return recipe_id, title, rating and nutritional values. Rating must not be null";
select *
from ML.generate_text(
  model remote_models.gemini_pro,
  (
    select concat(prompt_query, to_json_string(json_object("recipe_id", n.recipe_id, "title", title,
                  "carbo", carbo, "total_fat", total_fat, "cholestrl", cholestrl, "sodium", sodium, "calories",calories, "iron", iron, "vitamin_c", vitamin_c, "vitamin_a", vitamin_a))) as prompt
    from magazine_recipes_stg.Nutrition n
    inner join magazine_recipes_stg.Recipes r on r.recipe_id = n.recipe_id
    limit 20
  ),
  struct(TRUE as flatten_json_output)
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                           ml_generate_text_llm_result  \
# 0   {"recipe_id":895,"title":"-Soy Sauce-","rating...
# 1   {"recipe_id":900,"title":"-White Granulated Su...
# 2   {"recipe_id":896,"title":"-Teriyaki Sauce-","r...
# 3   {"recipe_id":1172,"title":"Garlic-Soy Dipping ...
# 4   {"recipe_id":928,"title":"-Tortilla Chips-","r...
# 5   {"recipe_id":916,"title":"-Steak Sauce-","rati...
# 6   {"recipe_id":1084,"title":"Sonoma Turkey Risot...
# 7   {"recipe_id":1346,"title":"Grilled Whole Salmo...
# 8   {"recipe_id":586,"title":"Lima Beans and Ham",...
# 9   {"recipe_id":819,"title":"-Millet-","rating":2...
# 10  {"recipe_id": 1120, "title": "Garlic Lime Chic...
# 11  {"recipe_id":917,"title":"-Lowfat Cottage Chee...
# 12  {"recipe_id":1057,"title":"Jambalaya","rating"...
# 13  {"recipe_id":1073,"title":"Barbecued Chicken o...
# 14  {"recipe_id":477,"title":"Red Onion Potato Sal...
# 15  {"recipe_id":1198,"title":"Soy Barbecued Shrim...
# 16  {"recipe_id":584,"title":"Hearty Ribs and Bean...
# 17  {"recipe_id":1162,"title":"Smoky Broiled Catfi...
# 18  {"recipe_id":1133,"title":"Oysters on Pasta","...
# 19  {"recipe_id":1159,"title":"Native American Cat...
#
#    ml_generate_text_rai_result ml_generate_text_status  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6                         None
# 7                         None
# 8                         None
# 9                         None
# 10                        None
# 11                        None
# 12                        None
# 13                        None
# 14                        None
# 15                        None
# 16                        None
# 17                        None
# 18                        None
# 19                        None
#
#                                                prompt
# 0   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 1   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 2   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 3   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 4   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 5   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 6   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 7   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 8   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 9   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 10  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 11  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 12  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 13  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 14  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 15  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 16  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 17  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 18  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 19  Rate the nutritional value as: 1,2 or 3. 1 bei...

# %%
# Use the averages as a baseline
# %%bigquery
SELECT
  avg(cholestrl) as avg_cholestrl,
  avg(calories) as avg_calories,
  avg(sodium) as avg_sodium,
  avg(total_fat) as avg_total_fat,
  avg(carbo) as avg_carbo,
  avg(protien) as avg_protien,
  avg(iron) as avg_iron,
  avg(vitamin_c) as avg_vitamin_c,
  avg(vitamin_a) as avg_vitamin_a,
  avg(fiber) as avg_fiber
FROM magazine_recipes_stg.Nutrition
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    avg_cholestrl  avg_calories  avg_sodium  avg_total_fat  avg_carbo  \
# 0      36.166344    217.914465  341.498519       6.579032  26.963132
#
#    avg_protien  avg_iron  avg_vitamin_c  avg_vitamin_a  avg_fiber
# 0    12.203189  2.033702      23.133554    1721.366503   1.124624

# %%
# Prompt above was not descriptive enough, so we calculate exact numbers to compare the values to.
# %%bigquery
declare prompt_query STRING default "Rate the nutritional value as: 1,2 or 3. 1 being unhealthy, 2 being neutral, and 3 being  healthy. cholestrol above 36 is unhealthy, sodium above 341 is unhealthy, total fat above 18 is unhealthy, carbo above 26 is unhealthy, protein below 12 is unhealthy, iron below 2 is unhealthy, vitamin_c below 23 is unhealthy, vitamin_a below 1721 is unhealthy, fiber below 1 is unhealthy. If less than 5 metrics are unhealthy, the rating is 3. If 5 metrics are unhealthy, the rating is 2. If more than 5 metrics are unhealthy, the rating is 1. Return recipe_id, title, rating, nutritional values. Rating must not be null";
create or replace table magazine_recipes_stg_ai.nutrition_ratings_10 as
  select *
  from ML.generate_text(
    model remote_models.gemini_pro,
    (
      select concat(prompt_query, to_json_string(json_object("recipe_id", n.recipe_id, "title", title,
                    "carbo", carbo, "total_fat", total_fat, "cholestrl", cholestrl, "sodium", sodium, "calories",calories, "iron", iron, "vitamin_c", vitamin_c, "vitamin_a", vitamin_a))) as prompt
      from magazine_recipes_stg.Nutrition n
      inner join magazine_recipes_stg.Recipes r on r.recipe_id = n.recipe_id
      limit 20
    ),
    struct(TRUE as flatten_json_output)
  );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from magazine_recipes_stg_ai.nutrition_ratings_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                           ml_generate_text_llm_result  \
# 0   {"calories":8.28,"carbo":2.07,"cholestrl":0.0,...
# 1   {"calories":462.78,"carbo":27.39,"cholestrl":1...
# 2   {"calories":482.79,"carbo":1.38,"cholestrl":18...
# 3   {"calories":372.87,"carbo":40.37,"cholestrl":8...
# 4   {"calories":15.75,"carbo":2.87,"cholestrl":0.0...
# 5   {"calories":535.29,"carbo":75.82,"cholestrl":4...
# 6   {"recipe_id": 586, "title": "Lima Beans and Ha...
# 7   {"recipe_id": 1172, "title": "Garlic-Soy Dippi...
# 8   {"recipe_id":917,"title":"-Lowfat Cottage Chee...
# 9   {"calories":94.2,"carbo":18.37,"cholestrl":0.0...
# 10  {"calories":412.76,"carbo":21.86,"cholestrl":8...
# 11  {"calories":16.64,"carbo":4.16,"cholestrl":0.0...
# 12  {"calories":250.0,"carbo":7.12,"cholestrl":443...
# 13  {"calories":9.98,"carbo":1.53,"cholestrl":0.0,...
# 14  {"calories":130.24,"carbo":2.3,"cholestrl":85....
# 15  {"recipe_id": 584, "title": "Hearty Ribs and B...
# 16  {"calories":440.35,"carbo":47.27,"cholestrl":8...
# 17  {"calories":139.13,"carbo":18.01,"cholestrl":0...
# 18  {"recipe_id": 477, "title": "Red Onion Potato ...
# 19  {"recipe_id": 1120, "title": "Garlic Lime Chic...
#
#                                                prompt
# 0   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 1   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 2   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 3   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 4   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 5   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 6   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 7   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 8   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 9   Rate the nutritional value as: 1,2 or 3. 1 bei...
# 10  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 11  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 12  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 13  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 14  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 15  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 16  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 17  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 18  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 19  Rate the nutritional value as: 1,2 or 3. 1 bei...

# %%
# %%bigquery
# alter table magazine_recipes_stg.Nutrition add column health_rating integer;
# Out:
# Executing query with job ID: 98fcf46d-bec0-4344-81ee-8d9fc57a1dc9
# Query executing: 0.48s
# ERROR:
#  400 Column already exists: health_rating at [1:55]
#
# Location: US
# Job ID: 98fcf46d-bec0-4344-81ee-8d9fc57a1dc9

# %%
# %%bigquery
# update magazine_recipes_stg.Nutrition set health_rating =
#   (select CAST(json_value(ml_generate_text_llm_result, '$.rating') as INT64)
#    from magazine_recipes_stg_ai.nutrition_ratings_10
#    where recipe_id = CAST(json_value(ml_generate_text_llm_result, '$.recipe_id') as INT64))
# where 1=1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_stg.Nutrition
# where health_rating is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0   19

# %% [markdown]
# #### Apply at larger scale

# %%
# %%bigquery
# declare prompt_query STRING default "Rate the nutritional value as: 1,2 or 3. 1 being unhealthy, 2 being neutral, and 3 being  healthy. cholestrol above 36 is unhealthy, sodium above 341 is unhealthy, total fat above 18 is unhealthy, carbo above 26 is unhealthy, protein below 12 is unhealthy, iron below 2 is unhealthy, vitamin_c below 23 is unhealthy, vitamin_a below 1721 is unhealthy, fiber below 1 is unhealthy. If less than 5 metrics are unhealthy, the rating is 3. If 5 metrics are unhealthy, the rating is 2. If more than 5 metrics are unhealthy, the rating is 1. Return recipe_id, title, rating, nutritional values. Rating must not be null. Rating must be either 1,2, or 3";
# create or replace table magazine_recipes_stg_ai.nutrition_ratings as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("recipe_id", n.recipe_id, "title", title,
#                     "carbo", carbo, "total_fat", total_fat, "cholestrl", cholestrl, "sodium", sodium, "calories",calories, "iron", iron, "vitamin_c", vitamin_c, "vitamin_a", vitamin_a))) as prompt
#       from magazine_recipes_stg.Nutrition n
#       inner join magazine_recipes_stg.Recipes r on r.recipe_id = n.recipe_id
#     ),
#     struct(TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from magazine_recipes_stg_ai.nutrition_ratings
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                            ml_generate_text_llm_result  \
# 0    {"recipe_id":477,"title":"Red Onion Potato Sal...
# 1    {"calories":92.43,"carbo":17.67,"cholestrl":27...
# 2    {"calories":310.86,"carbo":34.21,"cholestrl":3...
# 3    {"calories":133.52,"carbo":12.43,"cholestrl":2...
# 4    {"calories":697.84,"carbo":90.24,"cholestrl":3...
# ..                                                 ...
# 873  {"calories":134.82,"carbo":22.4,"cholestrl":51...
# 874  {"calories":570.94,"carbo":53.85,"cholestrl":1...
# 875  {"calories":249.69,"carbo":52.92,"cholestrl":0...
# 876  {"calories":55.74,"carbo":13.14,"cholestrl":0....
# 877  {"calories":92.29,"carbo":16.77,"cholestrl":0....
#
#                                                 prompt
# 0    Rate the nutritional value as: 1,2 or 3. 1 bei...
# 1    Rate the nutritional value as: 1,2 or 3. 1 bei...
# 2    Rate the nutritional value as: 1,2 or 3. 1 bei...
# 3    Rate the nutritional value as: 1,2 or 3. 1 bei...
# 4    Rate the nutritional value as: 1,2 or 3. 1 bei...
# ..                                                 ...
# 873  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 874  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 875  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 876  Rate the nutritional value as: 1,2 or 3. 1 bei...
# 877  Rate the nutritional value as: 1,2 or 3. 1 bei...
#
# [878 rows x 2 columns]

# %%
# %%bigquery
# update magazine_recipes_stg.Nutrition set health_rating =
#   (select CAST(json_value(ml_generate_text_llm_result, '$.rating') as INT64)
#    from magazine_recipes_stg_ai.nutrition_ratings
#    where recipe_id = CAST(json_value(ml_generate_text_llm_result, '$.recipe_id') as INT64))
# where 1=1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_stg.Nutrition
# where health_rating is NULL
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0    5

# %%
# it appears that the AI was not able to determine a rating for 5 recipes despite the prompt, we will leave those as null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select health_rating, count(*) from magazine_recipes_stg.Nutrition
# group by health_rating
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    health_rating  f0_
# 0           <NA>    5
# 1              1   88
# 2              2  287
# 3              3  498

# %%
# %%bigquery
# create or replace table magazine_recipes_stg.Nutrition as
# select * except(data_source, load_time), data_source, load_time
# from  magazine_recipes_stg.Nutrition
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# update the datasource for recipes with health rating
# %%bigquery
update magazine_recipes_stg.Nutrition
set data_source = 'bird-ai'
where health_rating is not null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Delta Detection

# %%
'''tables that were changed and what changes were done:
- recipes (type was removed- records updated)
- nutrition (added heatlh score - records updated)
- ingredients (airtable and bird ingreidents condensed- records were removed and records were updated)
non delta detection but create/deletion of tables
- magazines, publications, and journalists : tables were deleted
- posts: table was created
'''

# %%
# for ingredients
# %%bigquery
select count(*) as num_updates
from magazine_recipes_csp.Ingredients t full join magazine_recipes_stg.Ingredients s
on t.ingredient_id = s.ingredient_id
where t.status_flag = true
and (s.ingredient_id is null and t.ingredient_id is not null
or s.data_source != t.data_source);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_updates
# 0           26

# %%
# process the deletes from ingredients
# %%bigquery
declare current_ts TIMESTAMP;
set current_ts = current_timestamp();
update magazine_recipes_csp.Ingredients
set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
where ingredient_id in (select t.ingredient_id
from magazine_recipes_csp.Ingredients t left join magazine_recipes_stg.Ingredients s
on t.ingredient_id = s.ingredient_id
where s.ingredient_id is null);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# for ingredients
# %%bigquery
select count(*) as num_updates
from magazine_recipes_csp.Ingredients t full join magazine_recipes_stg.Ingredients s
on t.ingredient_id = s.ingredient_id
where t.status_flag = true
and (s.ingredient_id is null and t.ingredient_id is not null
or s.data_source != t.data_source);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_updates
# 0            7

# %%
# process the updates from ingredients
# %%bigquery
declare current_ts TIMESTAMP;
set current_ts = current_timestamp();

create temp table updates as
  select s.*
  from magazine_recipes_csp.Ingredients t full join magazine_recipes_stg.Ingredients s
  on t.ingredient_id = s.ingredient_id
  and s.data_source != t.data_source
  where s.ingredient_id is not null;

update magazine_recipes_csp.Ingredients
set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
where ingredient_id in (select ingredient_id from updates);

insert into magazine_recipes_csp.Ingredients
  (ingredient_id, category, name, plural, data_source, load_time, effective_time, status_flag)
    (select ingredient_id, category, name, plural, data_source, load_time, current_ts, true
      from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_csp.Ingredients
# where status_flag = True
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  3350

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_stg.Ingredients
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  3350

# %%
# Nutrition CDC
# %%bigquery
alter table magazine_recipes_csp.Nutrition
  ADD column health_rating INT64;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from magazine_recipes_csp.Nutrition
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0          878

# %%
# %%bigquery
# select count(*) as num_updates
# from magazine_recipes_stg.Nutrition s join magazine_recipes_csp.Nutrition t
# on s.recipe_id = t.recipe_id
# where t.status_flag = true
# and (s.health_rating is not null and t.health_rating is null)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_updates
# 0          873

# %%
  # %%bigquery
  select s.*
  from magazine_recipes_csp.Nutrition t join magazine_recipes_stg.Nutrition s
  on s.recipe_id = t.recipe_id
  WHERE (s.health_rating is not null and t.health_rating is null) AND t.protien is NULL ;
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [recipe_id, protien, carbo, alcohol, total_fat, sat_fat, cholestrl, sodium, iron, vitamin_c, vitamin_a, fiber, pcnt_cal_carb, pcnt_cal_fat, pcnt_cal_prot, calories, health_rating, data_source, load_time]
# Index: []

# %%
# %%bigquery
# declare current_ts TIMESTAMP;
# set current_ts = current_timestamp();
#
# create temp table updates as
#   select s.*
#   from magazine_recipes_csp.Nutrition t join magazine_recipes_stg.Nutrition s
#   on s.recipe_id = t.recipe_id
#   WHERE (s.health_rating is not null and t.health_rating is null);
#
# update magazine_recipes_csp.Nutrition
# set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
# where recipe_id in (select recipe_id from updates);
#
# insert into magazine_recipes_csp.Nutrition
#   (recipe_id, protien, carbo, alcohol, total_fat, sat_fat, cholestrl, sodium, iron, vitamin_c, vitamin_a, fiber, pcnt_cal_carb, pcnt_cal_fat, pcnt_cal_prot, calories, health_rating, data_source, load_time, effective_time, status_flag)
#     (select recipe_id, protien, carbo, alcohol, total_fat, sat_fat, cholestrl, sodium, iron, vitamin_c, vitamin_a, fiber, pcnt_cal_carb, pcnt_cal_fat, pcnt_cal_prot, calories, health_rating, data_source, load_time, current_ts, true
#         from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_updates
# from magazine_recipes_stg.Nutrition s join magazine_recipes_csp.Nutrition t
# on s.recipe_id = t.recipe_id
# where t.status_flag = true
# AND (s.health_rating != t.health_rating )
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_updates
# 0            0

# %% [markdown]
# ## Recipes CDC

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_csp.Recipes
# where status_flag = false
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0    0

# %%
# discontinue records from consumption not in staging
# %%bigquery
update magazine_recipes_csp.Recipes
  set status_flag = FALSE, discontinue_time = timestamp_sub(current_timestamp(), interval 1 second)
  where recipe_id in (select t.recipe_id  from magazine_recipes_csp.Recipes t
                      left join magazine_recipes_stg.Recipes s
                      on t.recipe_id = s.recipe_id
                      where t.status_flag = true
                      and s.recipe_id is null);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_csp.Recipes
# where status_flag = false
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    f0_
# 0  153

# %%
# insert records without timestamps
# %%bigquery
declare current_ts TIMESTAMP;
set current_ts = current_timestamp();
insert into magazine_recipes_csp.Recipes(recipe_id, title, subtitle, servings, yield_unit, prep_min, cook_min, stnd_min, source, intro, directions, rating, ease_of_prep, note, page, slowcooker, link, last_made, data_source, load_time, effective_time, status_flag)
    (select recipe_id, title, subtitle, servings, yield_unit, prep_min, cook_min, stnd_min, source, intro, directions, rating, ease_of_prep, note, page, slowcooker, link, last_made, data_source, load_time, current_ts, true
        from (select s.recipe_id, s.title, s.subtitle, s.servings, s.yield_unit, s.prep_min, s.cook_min, s.stnd_min, s.source, s.intro, s.directions, s.rating, s.ease_of_prep, s.note, s.page, s.slowcooker, s.link, s.last_made, s.data_source, s.load_time
            from magazine_recipes_csp.Recipes t
                      join magazine_recipes_stg.Recipes s
                      on t.recipe_id = s.recipe_id
                      where t.status_flag = true
                      and t.type is not null));
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# discontinue records with timestamps
# %%bigquery
update magazine_recipes_csp.Recipes
  set status_flag = FALSE, discontinue_time = timestamp_sub(current_timestamp(), interval 1 second)
  where type is not null;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_csp.Recipes
# where status_flag = True
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  1023

# %%
# %%bigquery
# select count(*)
# from magazine_recipes_stg.Recipes
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  1023

# %% [markdown]
# ## Magazine, Journalist, and Publication CDC

# %%
# %%bigquery
# update magazine_recipes_csp.Magazines
#   set status_flag = FALSE, discontinue_time = timestamp_sub(current_timestamp(), interval 1 second)
#   where 1 = 1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update magazine_recipes_csp.Journalists
#   set status_flag = FALSE, discontinue_time = timestamp_sub(current_timestamp(), interval 1 second)
#   where 1 = 1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update magazine_recipes_csp.Publications
#   set status_flag = FALSE, discontinue_time = timestamp_sub(current_timestamp(), interval 1 second)
#   where 1 = 1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Add Posts and Users to Consumption

# %%
# %%bigquery
# create or replace table magazine_recipes_csp.Users(
#   user_id	INT64 not null,
#   username STRING not null,
#   f_name STRING not null,
#   l_name STRING not null,
#   age INT64 not null,
#   phone STRING not null,
#   state STRING not null,
#   data_source STRING not null,
#   load_time	TIMESTAMP not null,
#   effective_time TIMESTAMP default current_timestamp() not null,
#   discontinue_time TIMESTAMP,
#   status_flag BOOL not null,
#   primary key (user_id, effective_time) not enforced)
#   as select *, current_timestamp(), null, true
#   from magazine_recipes_stg.Users;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# create or replace table magazine_recipes_csp.Posts(
#   post_id INT64 not null,
#   recipe_id INT64 not null,
#   user_id INT64 not null,
#   page STRING not null,
#   timestamp_posted TIMESTAMP not null,
#   data_source STRING not null,
#   load_time	TIMESTAMP not null,
#   effective_time TIMESTAMP default current_timestamp() not null,
#   discontinue_time TIMESTAMP,
#   status_flag BOOL not null,
#   primary key (post_id, effective_time) not enforced)
#   as select *, current_timestamp(), null, true
#   from magazine_recipes_stg.Posts;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT * FROM shidcs329e.magazine_recipes_stg.__TABLES__
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     project_id            dataset_id                   table_id  \
# 0   shidcs329e  magazine_recipes_stg                Ingredients
# 1   shidcs329e  magazine_recipes_stg     Ingredients_duplicates
# 2   shidcs329e  magazine_recipes_stg                Journalists
# 3   shidcs329e  magazine_recipes_stg           Journalists_copy
# 4   shidcs329e  magazine_recipes_stg                  Magazines
# 5   shidcs329e  magazine_recipes_stg                  Nutrition
# 6   shidcs329e  magazine_recipes_stg                      Posts
# 7   shidcs329e  magazine_recipes_stg               Publications
# 8   shidcs329e  magazine_recipes_stg                   Quantity
# 9   shidcs329e  magazine_recipes_stg                    Recipes
# 10  shidcs329e  magazine_recipes_stg                      Users
# 11  shidcs329e  magazine_recipes_stg     ingredient_id_no_nulls
# 12  shidcs329e  magazine_recipes_stg                ingredients
# 13  shidcs329e  magazine_recipes_stg             ingredients_at
# 14  shidcs329e  magazine_recipes_stg          ingredients_trial
# 15  shidcs329e  magazine_recipes_stg                quantity_at
# 16  shidcs329e  magazine_recipes_stg       recipe_ingredient_at
# 17  shidcs329e  magazine_recipes_stg    type_predictions_raw_10
# 18  shidcs329e  magazine_recipes_stg  unique_ingredient_with_id
#
#     creation_time  last_modified_time  row_count  size_bytes  type
# 0   1707520137650       1712624321752       3350      190911     1
# 1   1712371310673       1712371310674          8         266     1
# 2   1711745811428       1711745892878         91        6242     1
# 3   1711745794545       1711745794545         90        6193     1
# 4   1707525393272       1707529056377         20         320     1
# 5   1712620361000       1712620405472        878      134279     1
# 6   1712619159362       1712619159363       1023       55916     1
# 7   1707527111554       1712349014421       1176       47040     1
# 8   1707517223718       1712376936432       5463      375634     1
# 9   1712620584232       1712620584233       1023      463849     1
# 10  1712619450589       1712619450590         91        7921     1
# 11  1711135412661       1711135412662         82        1424     1
# 12  1711135325064       1711135325065        347        5772     1
# 13  1711133830835       1711133830836         82        2900     1
# 14  1712372422615       1712372422615        347        5772     1
# 15  1711132634798       1711132634798        347       14574     1
# 16  1710721163236       1710721166747        145       23013     1
# 17  1712355351247       1712355351248         10        4989     1
# 18  1711133739192       1711133739192         82        1240     1

# %%
# %%bigquery
# drop table magazine_recipes_stg.recipe_ingredient_at;
# drop table magazine_recipes_stg.quantity_at;
# drop table magazine_recipes_stg.ingredients_trial;
# drop table magazine_recipes_stg.ingredients_at;
# drop table magazine_recipes_stg.ingredients;
# drop table magazine_recipes_stg.ingredient_id_no_nulls;
# drop table magazine_recipes_stg.Journalists_copy;
# drop table magazine_recipes_stg.Ingredients_duplicates;
# drop table magazine_recipes_stg.Journalists;
# drop table magazine_recipes_stg.Magazines;
# drop table magazine_recipes_stg.Publications;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# drop table magazine_recipes_stg.unique_ingredient_with_id;
# drop table magazine_recipes_stg.type_predictions_raw_10;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT * FROM shidcs329e.magazine_recipes_stg.__TABLES__
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    project_id            dataset_id     table_id  creation_time  \
# 0  shidcs329e  magazine_recipes_stg  Ingredients  1707520137650
# 1  shidcs329e  magazine_recipes_stg    Nutrition  1712620361000
# 2  shidcs329e  magazine_recipes_stg        Posts  1712619159362
# 3  shidcs329e  magazine_recipes_stg     Quantity  1707517223718
# 4  shidcs329e  magazine_recipes_stg      Recipes  1712620584232
# 5  shidcs329e  magazine_recipes_stg        Users  1712619450589
#
#    last_modified_time  row_count  size_bytes  type
# 0       1712624321752       3350      190911     1
# 1       1712620405472        878      134279     1
# 2       1712619159363       1023       55916     1
# 3       1712376936432       5463      375634     1
# 4       1712620584233       1023      463849     1
# 5       1712619450590         91        7921     1

# %% [markdown]
# # Enforcing PK and FK

# %%
# Add primary key for Recipes
# %%bigquery
alter table magazine_recipes_stg.Recipes
  add primary key (recipe_id) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Add primary key for nutrition
# %%bigquery
alter table magazine_recipes_stg.Nutrition
  add primary key (recipe_id) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Foreign Key for  Nutrition
# %%bigquery
alter table magazine_recipes_stg.Nutrition add foreign key (recipe_id)
  references magazine_recipes_stg.Recipes (recipe_id) not enforced
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Primary key for posts
# %%bigquery
alter table magazine_recipes_stg.Posts
  add primary key (post_id) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Primary Key for Users
# %%bigquery
alter table magazine_recipes_stg.Users
  add primary key (user_id) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Foreign Key for Posts
# %%bigquery
alter table magazine_recipes_stg.Posts add foreign key (recipe_id)
  references magazine_recipes_stg.Recipes (recipe_id) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# user_id Foreign Key for Posts
# %%bigquery
alter table magazine_recipes_stg.Posts add foreign key (user_id)
  references magazine_recipes_stg.Users (user_id) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Recipe_id foreign key for quantity
# %%bigquery
alter table magazine_recipes_stg.Quantity add foreign key (recipe_id)
  references magazine_recipes_stg.Recipes (recipe_id) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Checking Primary keys

# %%
# There are no duplicates in stg or csp for Users (We just made Users so there shouldn't be any updates reflected in csp )
# %%bigquery
SELECT user_id, count(*) from magazine_recipes_stg.Users
GROUP BY user_id
HAVING count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [user_id, f0_]
# Index: []

# %%
# Checking Recipes for duplicate PKs
# %%bigquery
SELECT recipe_id, count(*) from magazine_recipes_stg.Recipes
GROUP BY recipe_id
HAVING count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [recipe_id, f0_]
# Index: []

# %%
# We deleted Journalists from stg so let's just confirm that the csp has the right amount of updates
# The query returns three results as expected because we changed three existing journalists in p8
# %%bigquery
SELECT journalist_id, count(*) from magazine_recipes_csp.Journalists
GROUP BY journalist_id
HAVING count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    journalist_id  f0_
# 0             15    2
# 1              3    2
# 2             73    2

# %%
# This query returns no results as expected because between p8 and p9, no publication_ids have been altered
# furthermore this table will no longer be active which is hwy we're checking csp instead of stg
# %%bigquery
SELECT publication_id, count(*) from magazine_recipes_csp.Publications
GROUP BY publication_id
HAVING count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [publication_id, f0_]
# Index: []

# %%
# Returns zero results - This also means there are no duplicated PKs in csp either
# %%bigquery
select post_id, count(*) from magazine_recipes_stg.Posts
GROUP BY post_id
HAVING count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [post_id, f0_]
# Index: []

# %%
# Check duplicate PKs in ingredients - there are none!
# In csp there are two of almost every id because we updated all but maybe 7 to 14 ingredients in p9
# %%bigquery
SELECT ingredient_id, count(*) from magazine_recipes_stg.Ingredients
GROUP BY ingredient_id
HAVING count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [ingredient_id, f0_]
# Index: []

# %%
# Check duplicate PKs in Nutrition
# %%bigquery
SELECT recipe_id, count(*) from magazine_recipes_stg.Nutrition
GROUP BY recipe_id
HAVING count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [recipe_id, f0_]
# Index: []

# %% [markdown]
# ## Checking Foreign Keys for New Tables

# %%
# %%bigquery
# select count(*) as orphan_records
# from magazine_recipes_stg.Posts
# where recipe_id not in (select recipe_id from  magazine_recipes_stg.Recipes)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %%
# Orphan records for Quantity
# %%bigquery
select count(*) as orphan_records
from magazine_recipes_stg.Quantity
where recipe_id not in (select recipe_id from  magazine_recipes_stg.Recipes)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %%
# Orpahn Records for Nutrition
# %%bigquery
select count(*) as orphan_records
from magazine_recipes_stg.Nutrition
where recipe_id not in (select recipe_id from  magazine_recipes_stg.Recipes)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %% [markdown]
# ## Fixing Orphan Records for Posts

# %% [markdown]
# In P8 we deleted some Users but we never fixed the posts that were associated with them. Here we'll reassign the correct post_id to the orphan posts

# %%
# %%bigquery
# SELECT *
# FROM magazine_recipes_stg.Users
# WHERE user_id > 90
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    user_id             username   f_name       l_name  age         phone  \
# 0       92          ChefJimmy92    Jimmy        Falon   22  214-417-1738
# 1       93  MattsMarvelousMeals  Matthew  McConaughey   33  972-732-6574
# 2       94     TrishaPieQueen94   Trisha       Paytas   40  817-370-7063
# 3       91   TaylorsTastyTreats   Taylor        Swift   64  682-270-4005
#
#   state data_source                        load_time
# 0    HI    faker-ai 2024-03-29 20:34:11.191045+00:00
# 1    WI    faker-ai 2024-03-29 20:34:11.191045+00:00
# 2    CA    faker-ai 2024-03-29 20:34:11.191045+00:00
# 3    NY    faker-ai 2024-03-29 20:34:11.191045+00:00

# %%
# %%bigquery
# CREATE OR REPLACE TABLE magazine_recipes_csp.Posts_copy AS
# SELECT
#   post_id,
#   recipe_id,
#   CASE
#     WHEN user_id = 88 THEN 91
#     WHEN user_id = 89 THEN 92
#     WHEN user_id = 90 THEN 93
#     ELSE user_id
#   END AS user_id,
#   page,
#   timestamp_posted,
#   data_source,
#   load_time,
#   effective_time,
#   discontinue_time,
#   status_flag
# FROM
#   magazine_recipes_csp.Posts
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# CREATE OR REPLACE TABLE magazine_recipes_stg.Posts_copy AS
# SELECT
#   post_id,
#   recipe_id,
#   CASE
#     WHEN user_id = 88 THEN 91
#     WHEN user_id = 89 THEN 92
#     WHEN user_id = 90 THEN 93
#     ELSE user_id
#   END AS user_id,
#   page,
#   timestamp_posted,
#   datasource,
#   load_time
# FROM
#   magazine_recipes_stg.Posts
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# DROP TABLE magazine_recipes_csp.Posts;
# drop table magazine_recipes_stg.Posts;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# ALTER TABLE magazine_recipes_csp.Posts_copy RENAME TO Posts;
# ALTER TABLE magazine_recipes_stg.Posts_copy RENAME TO Posts;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# FIXED !!
# %%bigquery
select count(*) as orphan_records
from magazine_recipes_stg.Posts
where user_id not in (select user_id from  magazine_recipes_stg.Users)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %%
# %%bigquery
# select count(*) as orphan_records
# from magazine_recipes_stg.Quantity
# where recipe_id not in (select recipe_id from  magazine_recipes_stg.Recipes)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %%
# %%bigquery
# select count(*) as orphan_records
# from magazine_recipes_stg.Quantity
# where ingredient_id not in (select ingredient_id from  magazine_recipes_stg.Ingredients)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %% [markdown]
# ### End Project 9 Work

# %%
# as a fun final outtake, we will share the odes the AI came up with when we prompted it to have fun!
# %%bigquery
DECLARE prompt_query STRING DEFAULT "have fun with it!";
SELECT *
FROM ML.generate_text(
  MODEL remote_models.gemini_pro,
  (
    SELECT CONCAT(prompt_query, TO_JSON_STRING(JSON_OBJECT("ingredient_id", ingredient_id, "ingredient_name", name))) AS prompt
    FROM magazine_recipes_stg.Ingredients
    WHERE data_source = 'Airtable'
    ORDER BY ingredient_id
  )
);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                               ml_generate_text_result ml_generate_text_status  \
# 0   {"candidates":[{"content":{"parts":[{"text":"*...
# 1   {"candidates":[{"content":{"parts":[{"text":"*...
# 2   {"candidates":[{"content":{"parts":[{"text":"*...
# 3   {"candidates":[{"content":{"parts":[{"text":"*...
# 4   {"candidates":[{"content":{"parts":[{"text":"*...
# 5   {"candidates":[{"content":{"parts":[{"text":"*...
# 6   {"candidates":[{"content":{"parts":[{"text":"*...
# 7   {"candidates":[{"content":{"parts":[{"text":"*...
# 8   {"candidates":[{"content":{"parts":[{"text":"*...
# 9   {"candidates":[{"content":{"parts":[{"text":"*...
# 10  {"candidates":[{"content":{"parts":[{"text":"*...
# 11  {"candidates":[{"content":{"parts":[{"text":"*...
# 12  {"candidates":[{"content":{"parts":[{"text":"*...
# 13  {"candidates":[{"content":{"parts":[{"text":"*...
# 14  {"candidates":[{"content":{"parts":[{"text":"*...
#
#                                                prompt
# 0   have fun with it!{"ingredient_id":4646,"ingred...
# 1   have fun with it!{"ingredient_id":4647,"ingred...
# 2   have fun with it!{"ingredient_id":4649,"ingred...
# 3   have fun with it!{"ingredient_id":4650,"ingred...
# 4   have fun with it!{"ingredient_id":4652,"ingred...
# 5   have fun with it!{"ingredient_id":4653,"ingred...
# 6   have fun with it!{"ingredient_id":4654,"ingred...
# 7   have fun with it!{"ingredient_id":4655,"ingred...
# 8   have fun with it!{"ingredient_id":4657,"ingred...
# 9   have fun with it!{"ingredient_id":4659,"ingred...
# 10  have fun with it!{"ingredient_id":4660,"ingred...
# 11  have fun with it!{"ingredient_id":4665,"ingred...
# 12  have fun with it!{"ingredient_id":4666,"ingred...
# 13  have fun with it!{"ingredient_id":4667,"ingred...
# 14  have fun with it!{"ingredient_id":4668,"ingred...
